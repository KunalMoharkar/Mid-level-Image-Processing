# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


img = cv2.imread("images/fingerprint.png")
img =cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

print(img)

ret,img1 = cv2.threshold(img,254,255,cv2.THRESH_BINARY)

print(img1)

plt.figure(figsize=(16,12))
plt.subplot(2,2,1)
plt.imshow(img,cmap='gray')
plt.title('Mask Image')
plt.xticks([])
plt.yticks([])
plt.subplot(2,2,2)
plt.imshow(img1)
plt.title('Inverse Mask Image')
plt.xticks([])
plt.yticks([])
# Out:
# [[255 255 255 ... 255 255 255]
#  [255 188 174 ... 254 178 174]
#  [255  42   0 ... 187   9   0]
#  ...
#  [255 255 255 ...   0   0   0]
#  [255 255 255 ...   0   0   0]
#  [255 255 255 ...  94  94  94]]
# [[255 255 255 ... 255 255 255]
#  [255   0   0 ...   0   0   0]
#  [255   0   0 ...   0   0   0]
#  ...
#  [255 255 255 ...   0   0   0]
#  [255 255 255 ...   0   0   0]
#  [255 255 255 ...   0   0   0]]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-06e41c8fe72e> in <module>
#      17 plt.subplot(2,2,1)
#      18 plt.imshow(img)
# ---> 19 plt.title('Mask Image',cmap='gray')
#      20 plt.xticks([])
#      21 plt.yticks([])
#
# c:\users\kumar\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\pyplot.py in title(label, fontdict, loc, pad, y, **kwargs)
#    3107 def title(label, fontdict=None, loc=None, pad=None, *, y=None, **kwargs):
#    3108     return gca().set_title(
# -> 3109         label, fontdict=fontdict, loc=loc, pad=pad, y=y, **kwargs)
#    3110
#    3111
#
# c:\users\kumar\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\axes\_axes.py in set_title(self, label, fontdict, loc, pad, y, **kwargs)
#     191         if fontdict is not None:
#     192             title.update(fontdict)
# --> 193         title.update(kwargs)
#     194         return title
#     195
#
# c:\users\kumar\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\text.py in update(self, kwargs)
#     177         # Update bbox last, as it depends on font properties.
#     178         bbox = kwargs.pop("bbox", sentinel)
# --> 179         super().update(kwargs)
#     180         if bbox is not sentinel:
#     181             self.set_bbox(bbox)
#
# c:\users\kumar\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\artist.py in update(self, props)
#     994                     func = getattr(self, f"set_{k}", None)
#     995                     if not callable(func):
# --> 996                         raise AttributeError(f"{type(self).__name__!r} object "
#     997                                              f"has no property {k!r}")
#     998                     ret.append(func(v))
#
# AttributeError: 'Text' object has no property 'cmap'
